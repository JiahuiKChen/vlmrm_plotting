# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### CLIP Global Steps & GT Reward

# %%
#load global step csv to convert from update number to steps
clip_step_csv = pd.read_csv("csv/siglip_mp_global_step.csv")
print(len(clip_step_csv))
print(clip_step_csv.columns)
clip_step_csv.head()
# Out:
# 1829
# Index(['Step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - global_step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - global_step',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_cosine_20240426_193423 - global_step',
#        'CartPole_siglip-base-patch16-224k_cosine_20240426_193423 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_cosine_20240426_193423 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_cosine_20240426_193211 - global_step',
#        'CartPole_siglip-base-patch16-224k_cosine_20240426_193211 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_cosine_20240426_193211 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_192935 - global_step',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_192935 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_192935 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_192417 - global_step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_192417 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_192417 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_160730 - global_step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_160730 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240426_160730 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_cosine_20240425_062033 - global_step',
#        'CartPole_siglip-base-patch16-224k_cosine_20240425_062033 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_cosine_20240425_062033 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_cosine_20240425_061736 - global_step',
#        'CartPole_siglip-base-patch16-224k_cosine_20240425_061736 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_cosine_20240425_061736 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240425_061326 - global_step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240425_061326 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240425_061326 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - global_step',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step__MAX',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - global_step',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - global_step__MIN',
#        'CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - global_step__MAX'],
#       dtype='object')
#    Step  \
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step__MIN  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step__MAX  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - global_step  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - global_step__MIN  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - global_step__MAX  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - global_step  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - global_step__MIN  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - global_step__MAX  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_061326 - global_step__MAX  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - global_step  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - global_step__MIN  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - global_step__MAX  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step__MIN  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step__MAX  \
# 0                                              75200
# 1                                              76800
# 2                                              78400
# 3                                              80000
# 4                                              81600
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - global_step  \
# 0                                            76800.0
# 1                                            83200.0
# 2                                            89600.0
# 3                                            96000.0
# 4                                           102400.0
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - global_step__MIN  \
# 0                                            76800.0
# 1                                            83200.0
# 2                                            89600.0
# 3                                            96000.0
# 4                                           102400.0
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - global_step__MAX
# 0                                            76800.0
# 1                                            83200.0
# 2                                            89600.0
# 3                                            96000.0
# 4                                           102400.0
#
# [5 rows x 43 columns]

# %%
#load in reward csv
clip_reward_csv = pd.read_csv("csv/siglip_mp_ep_gt_rew_mean.csv")
print(len(clip_reward_csv))
# print(len(clip_reward_csv.columns))
# print(clip_reward_csv.columns)
clip_reward_csv.head()
# Out:
# 1829
#    Step  \
# 0     0
# 1     1
# 2     2
# 3     3
# 4     4
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - rollout/ep_gt_rew_mean  \
# 0                                          31.747341
# 1                                          31.513298
# 2                                          31.462767
# 3                                          30.989361
# 4                                          30.813829
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - rollout/ep_gt_rew_mean__MIN  \
# 0                                          31.747341
# 1                                          31.513298
# 2                                          31.462767
# 3                                          30.989361
# 4                                          30.813829
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - rollout/ep_gt_rew_mean__MAX  \
# 0                                          31.747341
# 1                                          31.513298
# 2                                          31.462767
# 3                                          30.989361
# 4                                          30.813829
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - rollout/ep_gt_rew_mean  \
# 0                                          31.747341
# 1                                          31.513298
# 2                                          31.462767
# 3                                          30.989361
# 4                                          30.813829
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - rollout/ep_gt_rew_mean__MIN  \
# 0                                          31.747341
# 1                                          31.513298
# 2                                          31.462767
# 3                                          30.989361
# 4                                          30.813829
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240426_193951 - rollout/ep_gt_rew_mean__MAX  \
# 0                                          31.747341
# 1                                          31.513298
# 2                                          31.462767
# 3                                          30.989361
# 4                                          30.813829
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - rollout/ep_gt_rew_mean  \
# 0                                          31.747341
# 1                                          31.484043
# 2                                          31.414894
# 3                                          31.098404
# 4                                          30.992022
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - rollout/ep_gt_rew_mean__MIN  \
# 0                                          31.747341
# 1                                          31.484043
# 2                                          31.414894
# 3                                          31.098404
# 4                                          30.992022
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240426_193614 - rollout/ep_gt_rew_mean__MAX  \
# 0                                          31.747341
# 1                                          31.484043
# 2                                          31.414894
# 3                                          31.098404
# 4                                          30.992022
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_061326 - rollout/ep_gt_rew_mean__MAX  \
# 0                                          30.962767
# 1                                          30.877659
# 2                                          31.010639
# 3                                          31.228724
# 4                                          31.664894
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - rollout/ep_gt_rew_mean  \
# 0                                          31.747341
# 1                                          31.497341
# 2                                          31.553192
# 3                                          31.117022
# 4                                          30.819149
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - rollout/ep_gt_rew_mean__MIN  \
# 0                                          31.747341
# 1                                          31.497341
# 2                                          31.553192
# 3                                          31.117022
# 4                                          30.819149
#
#    CartPole_siglip-base-patch16-224k_contrastive_20240425_060203 - rollout/ep_gt_rew_mean__MAX  \
# 0                                          31.747341
# 1                                          31.497341
# 2                                          31.553192
# 3                                          31.117022
# 4                                          30.819149
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - rollout/ep_gt_rew_mean  \
# 0                                          31.747341
# 1                                          31.779255
# 2                                          31.803192
# 3                                          31.263298
# 4                                          30.957447
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - rollout/ep_gt_rew_mean__MIN  \
# 0                                          31.747341
# 1                                          31.779255
# 2                                          31.803192
# 3                                          31.263298
# 4                                          30.957447
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - rollout/ep_gt_rew_mean__MAX  \
# 0                                          31.747341
# 1                                          31.779255
# 2                                          31.803192
# 3                                          31.263298
# 4                                          30.957447
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - rollout/ep_gt_rew_mean  \
# 0                                          30.992188
# 1                                          30.859375
# 2                                          31.492188
# 3                                          31.502604
# 4                                          30.838541
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - rollout/ep_gt_rew_mean__MIN  \
# 0                                          30.992188
# 1                                          30.859375
# 2                                          31.492188
# 3                                          31.502604
# 4                                          30.838541
#
#    CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240424_150631 - rollout/ep_gt_rew_mean__MAX
# 0                                          30.992188
# 1                                          30.859375
# 2                                          31.492188
# 3                                          31.502604
# 4                                          30.838541
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Env Reward Global Step & Reward

# %%
#load global step csv to convert from update number to steps
gt_step_csv = pd.read_csv("csv/cartpole_gt_global_step.csv")
print(len(gt_step_csv))
gt_step_csv.head()
# Out:
# 468
#    Step  CartPole_env_reward_20240422_232316 - global_step  \
# 0     0                                               6400
# 1     1                                              12800
# 2     2                                              19200
# 3     3                                              25600
# 4     4                                              32000
#
#    CartPole_env_reward_20240422_232316 - global_step__MIN  \
# 0                                               6400
# 1                                              12800
# 2                                              19200
# 3                                              25600
# 4                                              32000
#
#    CartPole_env_reward_20240422_232316 - global_step__MAX
# 0                                               6400
# 1                                              12800
# 2                                              19200
# 3                                              25600
# 4                                              32000

# %%
#load in reward csv
gt_reward_csv = pd.read_csv("csv/cartpole_gt_ep_rew_mean.csv")
print(len(gt_reward_csv))
gt_reward_csv.head()
# Out:
# 468
#    Step  CartPole_env_reward_20240422_232316 - rollout/ep_rew_mean  \
# 0     0                                          31.812500
# 1     1                                          30.734375
# 2     2                                          31.572916
# 3     3                                          30.790001
# 4     4                                          30.250000
#
#    CartPole_env_reward_20240422_232316 - rollout/ep_rew_mean__MIN  \
# 0                                          31.812500
# 1                                          30.734375
# 2                                          31.572916
# 3                                          30.790001
# 4                                          30.250000
#
#    CartPole_env_reward_20240422_232316 - rollout/ep_rew_mean__MAX
# 0                                          31.812500
# 1                                          30.734375
# 2                                          31.572916
# 3                                          30.790001
# 4                                          30.250000

# %% [markdown]
# ### Plotting

# %%
# convert step col to global step 
clip_reward_csv["Step"] = clip_step_csv[clip_step_csv.columns[1]]
gt_reward_csv["Step"] = gt_step_csv[gt_step_csv.columns[1]]

# dropping min/max cols 
clip_reward_csv.drop([col for col in clip_reward_csv.columns if 'MAX' in col],axis=1,inplace=True)
clip_reward_csv.drop([col for col in clip_reward_csv.columns if 'MIN' in col],axis=1,inplace=True)

# renaming SIGLIP runs to have: reward func, multi or single prompt
def rename_clip(name):
    # which runs are multi-prompt and which are single prompt
    mp = {'193951', '193614', '193423', '193211', '192935', '192417'}
    mp_neg = {'160730', '194149'}

    if "Step" in name:
        return name
        
    # getting reward func
    if "cosine" in name:
        r = "cosine"
    elif "contrastive" in name:
        r = "contrastive"
    elif "goal_baseline" in name:
        r = "goal_baseline_reg"

    id = name.split('_')[4 if "goal_baseline" not in name else 6].split()[0]
    # print(f"{id} \t {name}")
    if id in mp:
        mp = "multi-prompt"
    elif id in mp_neg:
        mp = "multi-prompt-negative"
    else:
        mp = "single-prompt"
    return f"{r}_{mp}"

clip_reward_csv = clip_reward_csv.rename(columns=rename_clip)

# clip_reward_csv.columns

# %%
def moving_window_average(data, window_size):
    """Smooth data with moving window average."""
    if window_size <= 1:
        return data
    window = np.ones(int(window_size)) / float(window_size)
    return np.convolve(data, window, 'same')

# %%
clip_reward_csv.columns
# Out:
# Index(['Step', 'contrastive_multi-prompt-negative', 'contrastive_multi-prompt',
#        'goal_baseline_reg_multi-prompt', 'cosine_multi-prompt',
#        'cosine_multi-prompt', 'goal_baseline_reg_multi-prompt',
#        'contrastive_multi-prompt', 'contrastive_multi-prompt-negative',
#        'cosine_single-prompt', 'cosine_single-prompt',
#        'contrastive_single-prompt', 'contrastive_single-prompt',
#        'goal_baseline_reg_single-prompt', 'goal_baseline_reg_single-prompt'],
#       dtype='object')

# %%
# given a reward function and all the data, plot one line for each reward function
def plot(df, r):
    df = df.interpolate(method='linear')
    # Define smooth factor (window size), where the window size is 2k+1
    smooth_factor = 1
    prompt_type = ["multi-prompt", "single-prompt"]
    plt.figure(figsize=(10, 5))

    if r == "contrastive":
        name = f"{r}_multi-prompt-negative"

        # calculate average, std dev (2 runs with same name correspond to same seeds)
        means = clip_reward_csv[[name]].mean(axis=1)
        stds = clip_reward_csv[[name]].std(axis=1)
        # Apply smoothing
        smoothed_means = moving_window_average(means, smooth_factor)

        plt.plot(clip_step_csv['CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step'], smoothed_means, label=name, color='r')
        plt.fill_between(clip_step_csv['CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step'], smoothed_means-stds, smoothed_means+stds, alpha=0.2, color='r')

    for p in prompt_type:
        name = f"{r}_{p}"

        # calculate average, std dev (2 runs with same name correspond to same seeds)
        means = clip_reward_csv[[name]].mean(axis=1)
        stds = clip_reward_csv[[name]].std(axis=1)
        # Apply smoothing
        smoothed_means = moving_window_average(means, smooth_factor)

        if r == "cosine":
            x = clip_step_csv['CartPole_siglip-base-patch16-224k_cosine_20240425_062033 - global_step']
        elif r == "contrastive":
            x = clip_step_csv['CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step']
        elif r == "goal_baseline_reg":
            x = clip_step_csv['CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step']
        plt.plot(x, smoothed_means, label=name)
        plt.fill_between(x, smoothed_means-stds, smoothed_means+stds, alpha=0.2)

    # Plotting env reward
    # TODO: add in second run
    env_reward = gt_reward_csv["CartPole_env_reward_20240422_232316 - rollout/ep_rew_mean"]
    plt.plot(gt_reward_csv["Step"], env_reward, label="Environment Reward")
    
    # Labeling the plot
    plt.xlabel('Step')
    plt.ylabel('Episode Reward')
    if r == 'goal_baseline_reg':
        title = "Goal-Baseline-Regularized"
    else:
        title = r.capitalize()
    plt.title(f'{title} Reward')
    # plt.legend(loc=(1.04, 0))
    plt.legend()
    plt.show()

# %%
plot(clip_reward_csv, "contrastive")

# %%
plot(clip_reward_csv, "cosine")

# %%
plot(clip_reward_csv, "goal_baseline_reg")

# %% [markdown]
# ## One Plot with All Siglip Runs

# %%
# TODO: add ground truth reward

clip_reward_csv = clip_reward_csv.interpolate(method="linear")
smooth_factor = 1
# plot a line for each reward function and prompt/multi-prompt combination
rewards = ["cosine", "contrastive", "goal_baseline_reg"]
# "multi-prompt-negative" for contrastive only
prompt_type = ["multi-prompt", "single-prompt"]
plt.figure(figsize=(10, 10))

for r in rewards:
    for p in prompt_type:
        name = f"{r}_{p}"

        # calculate average, std dev (2 runs with same name correspond to same seeds)
        means = clip_reward_csv[[name]].mean(axis=1)
        stds = clip_reward_csv[[name]].std(axis=1)
        # Apply smoothing
        smoothed_means = moving_window_average(means, smooth_factor)

        if r == "cosine":
            x = clip_step_csv['CartPole_siglip-base-patch16-224k_cosine_20240425_062033 - global_step']
        elif r == "contrastive":
            x = clip_step_csv['CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step']
        elif r == "goal_baseline_reg":
            x = clip_step_csv['CartPole_siglip-base-patch16-224k_goal_baseline_reg_20240425_053932 - global_step']
        plt.plot(x, smoothed_means, label=name)
        plt.fill_between(x, smoothed_means-stds, smoothed_means+stds, alpha=0.2)

    if r == "contrastive":
        name = f"{r}_multi-prompt-negative"

        # calculate average, std dev (2 runs with same name correspond to same seeds)
        means = clip_reward_csv[[name]].mean(axis=1)
        stds = clip_reward_csv[[name]].std(axis=1)
        # Apply smoothing
        smoothed_means = moving_window_average(means, smooth_factor)

        plt.plot(clip_step_csv['CartPole_siglip-base-patch16-224k_contrastive_20240426_194149 - global_step'], smoothed_means, label=name)
        plt.fill_between(x, smoothed_means-stds, smoothed_means+stds, alpha=0.2)

    # ground truth reward
    env_reward = gt_reward_csv["CartPole_env_reward_20240422_232316 - rollout/ep_rew_mean"]
    plt.plot(gt_reward_csv["Step"], env_reward, label="Enviornment Reward")

# Labeling the plot
plt.xlabel('Step')
plt.ylabel('Score')
plt.title(f'Multiprompt vs Single Prompt Reward')
plt.legend(prop={'size': 10}, loc=(1.04, 0))
plt.show()
